# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/healthcare_raw.csv")

# %%
df
# Out:
#     Patient_ID  Gender  Age Medical_Condition Admission_Date Admission_Type  \
# 0        P1001    Male   45      Hypertension     15-01-2026         Urgent
# 1        P1002  Female   32         Pneumonia     16-01-2026      Emergency
# 2        P1003    Male   68   Diabetes Type 2     16-01-2026        Routine
# 3        P1004  Female   55            Asthma     17-01-2026      Emergency
# 4        P1005    Male   29          Fracture     17-01-2026         Urgent
# ..         ...     ...  ...               ...            ...            ...
# 495      P1496  Female   50              COPD     20-09-2026      Emergency
# 496      P1497    Male   28          Fracture     20-09-2026         Urgent
# 497      P1498  Female   67      Heart Attack     21-09-2026      Emergency
# 498      P1499    Male   43   Diabetes Type 2     21-09-2026        Routine
# 499      P1500  Female   61            Stroke     22-09-2026      Emergency
#
#     Medical_Code  Billing_Amount Discharge_Date
# 0      ICD10 I10          4500.0     20-01-2026
# 1      ICD10 J18          6700.5     22-01-2026
# 2      ICD10 E11          3200.0     18-01-2026
# 3      ICD10 J45          5800.0     19-01-2026
# 4      ICD10 S52          8500.0     25-01-2026
# ..           ...             ...            ...
# 495    ICD10 J44          9800.0     23-09-2026
# 496    ICD10 S52          9400.0     24-09-2026
# 497    ICD10 I21         14200.0     25-09-2026
# 498    ICD10 E11          4900.0     23-09-2026
# 499    ICD10 I63         13900.0     26-09-2026
#
# [500 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Patient_ID         500 non-null    object
#  1   Gender             500 non-null    object
#  2   Age                500 non-null    int64
#  3   Medical_Condition  500 non-null    object
#  4   Admission_Date     500 non-null    object
#  5   Admission_Type     500 non-null    object
#  6   Medical_Code       485 non-null    object
#  7   Billing_Amount     500 non-null    float64
#  8   Discharge_Date     500 non-null    object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 35.3+ KB

# %%
df["Admission_Type"]=df["Admission_Type"].str.lower()

# %%
df["Medical_Code"]=df["Medical_Code"].fillna("Undefind")

# %%
df.isnull()
# Out:
#      Patient_ID  Gender    Age  Medical_Condition  Admission_Date  \
# 0         False   False  False              False           False
# 1         False   False  False              False           False
# 2         False   False  False              False           False
# 3         False   False  False              False           False
# 4         False   False  False              False           False
# ..          ...     ...    ...                ...             ...
# 495       False   False  False              False           False
# 496       False   False  False              False           False
# 497       False   False  False              False           False
# 498       False   False  False              False           False
# 499       False   False  False              False           False
#
#      Admission_Type  Medical_Code  Billing_Amount  Discharge_Date
# 0             False         False           False           False
# 1             False         False           False           False
# 2             False         False           False           False
# 3             False         False           False           False
# 4             False         False           False           False
# ..              ...           ...             ...             ...
# 495           False         False           False           False
# 496           False         False           False           False
# 497           False         False           False           False
# 498           False         False           False           False
# 499           False         False           False           False
#
# [500 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Patient_ID         500 non-null    object
#  1   Gender             500 non-null    object
#  2   Age                500 non-null    int64
#  3   Medical_Condition  500 non-null    object
#  4   Admission_Date     500 non-null    object
#  5   Admission_Type     500 non-null    object
#  6   Medical_Code       500 non-null    object
#  7   Billing_Amount     500 non-null    float64
#  8   Discharge_Date     500 non-null    object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 35.3+ KB

# %%
df['Admission_Type'].value_counts()
# Out:
# Admission_Type
# routine      196
# emergency    188
# urgent       116
# Name: count, dtype: int64

# %%
df['Admission_Date']=df['Admission_Date'].astype('datetime64[ns]')
df['Discharge_Date']=df['Discharge_Date'].astype('datetime64[ns]')

# %%
df["Hospital_stay_Days"]=(df['Discharge_Date'] - df['Admission_Date']).dt.days
df.head()
# Out:
#   Patient_ID  Gender  Age Medical_Condition Admission_Date Admission_Type  \
# 0      P1001    Male   45      Hypertension     2026-01-15         urgent
# 1      P1002  Female   32         Pneumonia     2026-01-16      emergency
# 2      P1003    Male   68   Diabetes Type 2     2026-01-16        routine
# 3      P1004  Female   55            Asthma     2026-01-17      emergency
# 4      P1005    Male   29          Fracture     2026-01-17         urgent
#
#   Medical_Code  Billing_Amount Discharge_Date  Hospital_stay_Days
# 0    ICD10 I10          4500.0     2026-01-20                   5
# 1    ICD10 J18          6700.5     2026-01-22                   6
# 2    ICD10 E11          3200.0     2026-01-18                   2
# 3    ICD10 J45          5800.0     2026-01-19                   2
# 4    ICD10 S52          8500.0     2026-01-25                   8

# %%
df[['Admission_Date', 'Medical_Code','Discharge_Date','Admission_Type','Hospital_stay_Days']].head()
# Out:
#   Admission_Date Medical_Code Discharge_Date Admission_Type  \
# 0     2026-01-15    ICD10 I10     2026-01-20         urgent
# 1     2026-01-16    ICD10 J18     2026-01-22      emergency
# 2     2026-01-16    ICD10 E11     2026-01-18        routine
# 3     2026-01-17    ICD10 J45     2026-01-19      emergency
# 4     2026-01-17    ICD10 S52     2026-01-25         urgent
#
#    Hospital_stay_Days
# 0                   5
# 1                   6
# 2                   2
# 3                   2
# 4                   8

# %%
df['Billing_Amount'].describe()
# Out:
# count      500.00000
# mean      7249.00100
# std       3198.96932
# min       2300.00000
# 25%       4400.00000
# 50%       6950.00000
# 75%       9400.00000
# max      14200.00000
# Name: Billing_Amount, dtype: float64

# %%
df["Medical_Condition"].value_counts()
# Out:
# Medical_Condition
# COPD                       34
# Appendicitis               33
# Stroke                     33
# Pneumonia                  31
# Heart Failure              30
# Kidney Stone               28
# Hypertension               28
# Heart Attack               27
# Fracture                   22
# Gastritis                  21
# Skin Infection             20
# Back Pain                  20
# Asthma                     19
# Parkinson's Disease        19
# Urinary Tract Infection    18
# Pregnancy                  16
# Diabetes Type 2            16
# Allergic Reaction          15
# Gallstones                 15
# Diabetes Type 1            15
# Osteoporosis               12
# Osteoarthritis             12
# Anxiety Disorder            9
# Migraine                    6
# Hypothyroidism              1
# Name: count, dtype: int64

# %%
df["Hospital_stay_Days"].describe()
# Out:
# count    500.000000
# mean       2.860000
# std       78.273046
# min     -291.000000
# 25%        2.000000
# 50%        3.000000
# 75%       61.000000
# max      184.000000
# Name: Hospital_stay_Days, dtype: float64

# %%
pd.crosstab(
    df['Admission_Type'],
    df['Medical_Condition']
)
# Out:
# Medical_Condition  Allergic Reaction  Anxiety Disorder  Appendicitis  Asthma  \
# Admission_Type
# emergency                          0                 0            33       1
# routine                            0                 9             0       0
# urgent                            15                 0             0      18
#
# Medical_Condition  Back Pain  COPD  Diabetes Type 1  Diabetes Type 2  \
# Admission_Type
# emergency                  0    34                0                0
# routine                    0     0               15               16
# urgent                    20     0                0                0
#
# Medical_Condition  Fracture  Gallstones  ...  Kidney Stone  Migraine  \
# Admission_Type                           ...
# emergency                 0           0  ...            28         0
# routine                   0          15  ...             0         6
# urgent                   22           0  ...             0         0
#
# Medical_Condition  Osteoarthritis  Osteoporosis  Parkinson's Disease  \
# Admission_Type
# emergency                       0             0                    0
# routine                        12            12                   19
# urgent                          0             0                    0
#
# Medical_Condition  Pneumonia  Pregnancy  Skin Infection  Stroke  \
# Admission_Type
# emergency                 31          0               0      33
# routine                    0         16               0       0
# urgent                     0          0              20       0
#
# Medical_Condition  Urinary Tract Infection
# Admission_Type
# emergency                                0
# routine                                 18
# urgent                                   0
#
# [3 rows x 25 columns]

# %%
df.groupby('Medical_Condition')['Age'].mean()
# Out:
# Medical_Condition
# Allergic Reaction          33.400000
# Anxiety Disorder           37.111111
# Appendicitis               33.090909
# Asthma                     41.894737
# Back Pain                  40.650000
# COPD                       65.176471
# Diabetes Type 1            50.200000
# Diabetes Type 2            52.375000
# Fracture                   38.909091
# Gallstones                 49.066667
# Gastritis                  40.047619
# Heart Attack               65.925926
# Heart Failure              64.433333
# Hypertension               53.392857
# Hypothyroidism             52.000000
# Kidney Stone               49.000000
# Migraine                   30.500000
# Osteoarthritis             53.166667
# Osteoporosis               54.166667
# Parkinson's Disease        72.631579
# Pneumonia                  57.709677
# Pregnancy                  29.187500
# Skin Infection             33.150000
# Stroke                     63.242424
# Urinary Tract Infection    43.777778
# Name: Age, dtype: float64
